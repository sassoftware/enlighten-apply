# %%
"""
Copyright (c) 2016 by SAS Institute
Licensed under the Apache License, Version 2.0 (the "License");
you may not use this file except in compliance with the License.
You may obtain a copy of the License at

   http://www.apache.org/licenses/LICENSE-2.0
   
Unless required by applicable law or agreed to in writing, software
distributed under the License is distributed on an "AS IS" BASIS,
WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
See the License for the specific language governing permissions and
limitations under the License.

"""

# %%
from swat import *
from pprint import pprint
from matplotlib import pyplot as plt
import pandas as pd
import os, sys
import numpy as np
from scipy import misc
from PIL import Image
from skimage import feature
import re
import csv

# CAS setup
cashost='rdcgrd001'
casport=xxxxx
casauth='C:/Users/xxxx/_authinfo'

# Start CAS session
sess = CAS(cashost, casport, authinfo=casauth, caslib="casuser")

# %%
path = 
#destPath = 
dirs = os.listdir( path )
nblocks   = 5
npixels   = 16
data      = []

# %%
for dir in dirs:
    print dir
    i = 1
    # read in .pgm images and save as .jpg
    dirname = path+"\\"+dir
    print dirname
    for file in os.listdir(dirname):
        imageFile = dirname + "\\" + file
        #destdirname = destPath+"\\"+dir
        try:
            os.stat(destdirname)
        except:
            os.mkdir(destdirname)
        print imageFile
        image = misc.imread(imageFile)
        #print image.shape
        #downsize images to 90x90, divide each image to 5x5 blocks
        sImage = misc.imresize(image, (90,90) )
        #outImgFile = destdirname + "\\" + "img" + str(i) + ".jpg"
        #misc.imsave(outImgFile, sImage)
        
        features  = []
        for j in range(nblocks):
            for k in range(nblocks):
                block = sImage[j*npixels:(j+1)*npixels,k*npixels:(k+1)*npixels]
                #outImgFile = destdirname + "\\" + "block" + str(i)+str(j) +str(k)+ ".jpg"
                #misc.imsave(outImgFile, block)
                
                block = block.reshape(1,block.shape[0]*block.shape[1])
                features.append(block)
                print np.array(features).shape
        i +=1
        features = np.array(features).reshape(1,block.shape[0]*block.shape[1]*nblocks*nblocks)
        personID = int(re.search(r'\d+', dir).group())
        #print personID
        features = np.append(features,personID)
        #print features
        data.append(features)
# Out:
# s1
# C:\users\ruzhan\Documents\work\faceRecog\LBP\att_faces\s1
# C:\users\ruzhan\Documents\work\faceRecog\LBP\att_faces\s1\1.pgm
# (112L, 92L)
# 0
# (1L, 1L, 256L)
# (2L, 1L, 256L)
# (3L, 1L, 256L)
# (4L, 1L, 256L)
# (5L, 1L, 256L)
# 1
# (6L, 1L, 256L)
# (7L, 1L, 256L)
# (8L, 1L, 256L)
# (9L, 1L, 256L)
# (10L, 1L, 256L)
# 2
# (11L, 1L, 256L)
# (12L, 1L, 256L)
# (13L, 1L, 256L)
# (14L, 1L, 256L)
# (15L, 1L, 256L)
# 3
# (16L, 1L, 256L)
# (17L, 1L, 256L)
# (18L, 1L, 256L)
# (19L, 1L, 256L)
# (20L, 1L, 256L)
# 4
# (21L, 1L, 256L)
# (22L, 1L, 256L)
# (23L, 1L, 256L)
# (24L, 1L, 256L)
# (25L, 1L, 256L)
# 1
# C:\users\ruzhan\Documents\work\faceRecog\LBP\att_faces\s1\10.pgm
# (112L, 92L)
# 0
# (1L, 1L, 256L)
# (2L, 1L, 256L)
# (3L, 1L, 256L)
# (4L, 1L, 256L)
# (5L, 1L, 256L)
# 1
# (6L, 1L, 256L)
# (7L, 1L, 256L)
# (8L, 1L, 256L)
# (9L, 1L, 256L)
# (10L, 1L, 256L)
# 2
# (11L, 1L, 256L)
# (12L, 1L, 256L)
# (13L, 1L, 256L)
# (14L, 1L, 256L)
# (15L, 1L, 256L)
# 3
# (16L, 1L, 256L)
# ...

# %%
print np.array(data).shape
np.savetxt("ORL2.csv", data, delimiter=",", fmt="%i")
# Out:
# (400L, 6401L)

# %%
varList = []
for i in range(np.array(data).shape[1]-1):
    temp = "Feature" + str(i+1)
    varList = np.append(varList,temp)
varList = np.append(varList,'ID')
#print varList
# Out:
# ['Feature1' 'Feature2' 'Feature3' ..., 'Feature6399' 'Feature6400' 'ID']

# %%
with open('ORL_full2.csv', 'wb') as outcsv:
    writer = csv.writer(outcsv)    
    writer.writerow(varList)
    
    with open('ORL2.csv', 'rb') as incsv:
        reader = csv.reader(incsv)
        writer.writerows(row  for row in reader)

# %%
out = sess.upload("ORL_full2.csv")
# Out:
# NOTE: Cloud Analytic Services made the uploaded file available as table ORL_FULL2 in caslib CASUSERHDFS(ruzhan).
# NOTE: The table ORL_FULL2 has been created in caslib CASUSERHDFS(ruzhan) from binary data uploaded to Cloud Analytic Services.

# %%
#data=sess.CASTable('ORL_FULL1')
#pprint(data.fetch(to=20))
# Out:
# CASResults([(u'Fetch',     Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0         52        49        49        53        51        53        52
# 1        118       119       118       119       120       120       120
# 2         58        52        47        49        52        52        48
# 3         55        50        48        50        48        49        51
# 4         47        48        51        50        51        48        51
# 5        121       121       121       122       122       121       122
# 6         45        49        50        47        48        49        51
# 7        121       121       121       122       123       122       122
# 8        109       110       113       111       109       111       110
# 9        108       106       104       106       104       106       106
# 10       104       105       106       104       104       105       103
# ...

# %%
allVars = []
for j in range(nblocks*nblocks):
    varList = []
    for i in range(j*npixels*npixels,(j+1)*npixels*npixels):
        temp = "Feature" + str(i+1)
        varList.append(temp)
    allVars.append(varList)
#print allVars
# Out:
# [['Feature1', 'Feature2', 'Feature3', 'Feature4', 'Feature5', 'Feature6', 'Feature7', 'Feature8', 'Feature9', 'Feature10', 'Feature11', 'Feature12', 'Feature13', 'Feature14', 'Feature15', 'Feature16', 'Feature17', 'Feature18', 'Feature19', 'Feature20', 'Feature21', 'Feature22', 'Feature23', 'Feature24', 'Feature25', 'Feature26', 'Feature27', 'Feature28', 'Feature29', 'Feature30', 'Feature31', 'Feature32', 'Feature33', 'Feature34', 'Feature35', 'Feature36', 'Feature37', 'Feature38', 'Feature39', 'Feature40', 'Feature41', 'Feature42', 'Feature43', 'Feature44', 'Feature45', 'Feature46', 'Feature47', 'Feature48', 'Feature49', 'Feature50', 'Feature51', 'Feature52', 'Feature53', 'Feature54', 'Feature55', 'Feature56', 'Feature57', 'Feature58', 'Feature59', 'Feature60', 'Feature61', 'Feature62', 'Feature63', 'Feature64', 'Feature65', 'Feature66', 'Feature67', 'Feature68', 'Feature69', 'Feature70', 'Feature71', 'Feature72', 'Feature73', 'Feature74', 'Feature75', 'Feature76', 'Feature77', 'Fea
# ...

# %%
sess.loadactionset(actionset="sampling")
sess.stratified(display={"names":"STRAFreq"},
                output={"casOut":{"name":"partORL", "replace":True}, "copyVars":"ALL"},
                samppct=10,  partind=True, seed=654321,
                table={"name":"ORL_FULL2", "groupBy":{"ID"}})
# Out:
# NOTE: Added action set 'sampling'.
# NOTE: Using SEED=654321 for sampling.
# CASResults([(u'outputSize', {u'outputNObs': 400.0, u'outputNVars': 6402}), (u'STRAFreq',     ByGrpID            ID  NObs  NSamp
# 0         0             1    10      1
# 1         1             2    10      1
# 2         2             3    10      1
# 3         3             4    10      1
# 4         4             5    10      1
# 5         5             6    10      1
# 6         6             7    10      1
# 7         7             8    10      1
# 8         8             9    10      1
# 9         9            10    10      1
# 10       10            11    10      1
# 11       11            12    10      1
# 12       12            13    10      1
# 13       13            14    10      1
# 14       14            15    10      1
# 15       15            16    10      1
# 16       16            17    10      1
# 17       17            18    10      1
# 18       18            19    10      1
# ...

# %%
#stra_out=sess.CASTable('partLBP')
#pprint(stra_out.fetch(to=20))
# Out:
# CASResults([(u'Fetch',     Feature1  Feature2  Feature3  Feature4  Feature5  Feature6  Feature7  \
# 0         76        28        53       122       120        49       111
# 1         25        72        63        85       101        95         0
# 2         25        72       111        23        57        52       127
# 3         25        72        38       122        50       127       235
# 4         76       243        63       207       127        56       127
# 5         76         4       159       151        76        70        15
# 6         25        72        63       127       223       215         6
# 7         51        26        47       127        82       255       239
# 8         76        52       143        47        95        52        15
# 9          0        71       255        68       191         0         3
# 10        76        52        56       107         0       175       235
# ...

# %%
sess.loadactionset(actionset="neuralNet")
    
def NNET(k,hiddenUnits,seed):
    NNETModel = "_NNET_MODEL_"+ str(k)
    NNETScore = "_NNET_SCORE_"+ str(k)

    sess.anntrain(acts={"TANH"},
              arch="MLP",randDist='UNIFORM', scaleInit=2, 
              casOut={"name":NNETModel, "replace":True}, 
              errorFunc="ENTROPY",
              hiddens={hiddenUnits},
              inputs = allVars[k],
              nloOpts={"algorithm":"lbfgs","optmlOpt":{"maxIters":250,"maxTime":510.0,"regL1":0.0001,"regL2":0.0001},
                       "printOpt":{"statusMsg":True}},
              seed=seed,
              std="MIDRANGE",
              target="ID",targetAct="SOFTMAX",nominals={'ID'},
              validtable={"name":"partORL","where":"_partIND_ = 1" },
              table={"name":"partORL","where":"_partIND_ = 0" })
    
    sess.annscore(#assess=True,
              assessOneRow=True,
              casOut={"name":NNETScore, "replace":True}, 
              model={"name":NNETModel},
              target="ID",
              encodeName = True,
              copyVars={"ID"},
              table={"name":"partORL","where":"_partIND_ = 1" })
    

for i in range(25):
    print i
    NNET(i,50,23451)
# Out:
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.
# NOTE: Added action set 'neuralNet'.

# %%
Str="data _nn_scored_merged;merge "
for i in range(25):
    temp = " _NNET_SCORE_"+str(i) +"(rename=(I_ID=I_ID"+str(i)+"))"
    Str = Str+temp
print (Str)
Str = Str + "; by ID; keep ID " 
for i in range(25):
    temp = " I_ID"+str(i)
    Str = Str+temp
print (Str)
Str = Str+"; run;"
# Out:
# data _nn_scored_merged;merge  _NNET_SCORE_0(rename=(I_ID=I_ID0)) _NNET_SCORE_1(rename=(I_ID=I_ID1)) _NNET_SCORE_2(rename=(I_ID=I_ID2)) _NNET_SCORE_3(rename=(I_ID=I_ID3)) _NNET_SCORE_4(rename=(I_ID=I_ID4)) _NNET_SCORE_5(rename=(I_ID=I_ID5)) _NNET_SCORE_6(rename=(I_ID=I_ID6)) _NNET_SCORE_7(rename=(I_ID=I_ID7)) _NNET_SCORE_8(rename=(I_ID=I_ID8)) _NNET_SCORE_9(rename=(I_ID=I_ID9)) _NNET_SCORE_10(rename=(I_ID=I_ID10)) _NNET_SCORE_11(rename=(I_ID=I_ID11)) _NNET_SCORE_12(rename=(I_ID=I_ID12)) _NNET_SCORE_13(rename=(I_ID=I_ID13)) _NNET_SCORE_14(rename=(I_ID=I_ID14)) _NNET_SCORE_15(rename=(I_ID=I_ID15)) _NNET_SCORE_16(rename=(I_ID=I_ID16)) _NNET_SCORE_17(rename=(I_ID=I_ID17)) _NNET_SCORE_18(rename=(I_ID=I_ID18)) _NNET_SCORE_19(rename=(I_ID=I_ID19)) _NNET_SCORE_20(rename=(I_ID=I_ID20)) _NNET_SCORE_21(rename=(I_ID=I_ID21)) _NNET_SCORE_22(rename=(I_ID=I_ID22)) _NNET_SCORE_23(rename=(I_ID=I_ID23)) _NNET_SCORE_24(rename=(I_ID=I_ID24))
# ...

# %%
sess.dataStep.runCode( 
    code=Str
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4f310d58567b> in <module>()
#       5
#       6 #allout=sess.CASTable("_nn_scored_merged")
# ----> 7 pred = fetch(table=table('_nn_scored_merged'))
#
# NameError: name 'fetch' is not defined

# %%
scores=sess.CASTable("_nn_scored_merged")
pred = scores.fetch(to=40)['Fetch']
Freqs = np.zeros((40,40))
ID = []
for i in range(40):
    index = int(pred.iloc[i].iloc[0])
    ID = np.append(ID,index)
    for j in range(1,26):
        index = int(pred.iloc[i].iloc[j].strip())-1
        Freqs[i][index] +=1
        
#print Freqs
p_ID = []
for i in range(40):
    tmpID = np.where(Freqs[i,]==max(Freqs[i,]))
    tmpID = min(tmpID[0]+1)
    p_ID = np.append(p_ID,tmpID)
# Out:
# 1.0
# [ 39.   1.   3.  35.   5.  17.  26.  37.   7.  19.  28.  31.   9.  13.  22.
#   33.  23.  15.  24.  11.  20.   2.   4.  18.  27.  36.   6.  29.  38.   8.
#   14.  23.  32.  16.  25.  34.  10.  12.  21.  30.]
# [ 39.   1.   3.  35.   5.  17.  26.  37.   7.  19.  28.  31.   9.  13.  22.
#   33.  40.  15.  24.  11.  20.   2.   4.  18.  27.  36.   6.  29.  38.   8.
#   14.  23.  32.  16.  25.  34.  10.  12.  21.  30.]

# %%
def calMisclas(arr1,arr2):
    n1 = len(arr1)
    n2 = len(arr2)
    if (n1==n2):
        nMisclas = 0
        for i in range(n1):
            if (arr2[i]!=arr1[i]):  
                nMisclas +=1
        ratio = nMisclas/float(n1)
    return ratio

# %%
misRate = calMisclas(ID,p_ID)*100
print misRate
# Out:
# 2.5
